# %%
import glob
import os
import pandas as pd
import re
from unicodedata import normalize
from tqdm.auto import tqdm
import re
# as per recommendation from @freylis, compile once only
CLEANR = re.compile('<.*?>') 

def cleanhtml(raw_html):
  cleantext = re.sub(CLEANR, '', raw_html)
  return cleantext

# %%
# def clean(path):
#     text = ''
#     page_view_line=0
#     with open(path,"r",encoding="utf-8-sig") as f:
#         for n, line in enumerate(f):
#             line = line.strip()
#             if n == 0:
#                 text = line + '\n'
#             else:
#                 if line:
#                     if re.match(r'^[\d,]+$', line):
#                         page_view_line = n
#                         continue
#                     if line == 'พิมพ์' and page_view_line and page_view_line < n: # skip 'print'
#                         continue
#                     if re.match(r'^ที่มา : http', line):
#                         text = text + '\n\n' + line + '\n'
#                     else:
#                         text = text + '\n' + line
#     return cleanhtml(normalize('NFKD', text)).strip()

# %%
def clean(path):
    text={"title":"","context":"","url":""}
    page_view_line = 0
    with open(path, 'r', encoding='utf-8-sig') as f:
        for n, line in enumerate(f):
            line = line.strip()
            if n == 0: # title line
                text["title"] = line.strip()
            else:
                if line:
                    if re.match(r'^[\d,]+$', line):
                        page_view_line = n
                        continue
                    if line == 'พิมพ์' or page_view_line and page_view_line < n: # skip 'print'
                        continue
                    if re.match(r'^ที่มา : http', line):
                        text["url"] = line.strip().split(" ")[-1]
                    else:
                        text["context"] +=line.strip().replace("\xa0","")+"\n"
    text["context"]=cleanhtml(normalize('NFKD', text["context"])).strip()
    return text

# %%
clean("./thaigov2-9/ข่าวทันสถานการณ์โควิด-19_1.txt")
# Out:
# {'title': 'รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-6 Trick ธุรกิจร้านอาหาร ปรับตัวต้าน COVID -19 [กระทรวงอุตสาหกรรม]',
#  'context': 'วันอังคารที่ 14 เมษายน 2563\n6 Trick ธุรกิจร้านอาหาร ปรับตัวต้าน COVID -19 [กระทรวงอุตสาหกรรม]\n6 Trick ธุรกิจร้านอาหาร ปรับตัวต้าน COVID -19\nในช่วงที่ไวรัสCOVID-19กําลังระบาดอย่างหนัก ธุรกิจร้านอาหารเป็นหนึ่งในธุรกิจที่ได้รับผลกระทบมากที่สุด เนื่องจากมาตรการต่าง ๆ ที่ลดการพบปะของผู้คนและการตระหนักระวังตัวมากขึ้นของลูกค้า วันนี้เราจึงมี6 Trickที่จะเป็นแนวทางให้ผู้ประกอบการธุรกิจร้านอาหารปรับตัวสู้กับภัยCOVID-19ได้ มาดูพร้อม ๆ กันว่ามีแนวทางใดที่เหมาะสมและสามารถนําไปปรับใช้ได้บ้าง\n1.บริการจัดส่งแบบDelivery\nเมื่อลูกค้าต่างหลีกเลี่ยงการเดินทางออกจากที่พักอาศัย การจัดส่งถึงบ้านแบบDeliveryจึงถือเป็นตัวเลือกที่ทุกร้านจําเป็นต้องทําในช่วงวิกฤตนี้ ร้านอาหารรายย่อยที่ไม่เคยสมัครใช้บริการธุรกิจจัดส่งอาหารจึงควรดําเนินการสมัครในทันที เนื่องจากต้องใช้เวลาประมาณ7วันจึงสามารถเริ่มต้นใช้งานได้หรืออาจทําการจัดส่งด้วยตัวเองก็ได้เช่นกัน นอกจากนั้น ร้านอาหารควรต้องเพิ่มสัดส่วนบริการจัดส่ง ตระเตรียมบรรจุภัณฑ์สําหรับใส่อาหารเพื่อการจัดส่งให้เหมาะสมอีกด้วย\n2.การจัดส่งแบบไร้สัมผัส (Contactless Delivery)\nสําหรับร้านค้าที่ดําเนินการจัดส่งด้วยตัวเอง เช่น ร้านปาท่องโก๋ที่มีบริการจัดส่งให้ลูกค้าทุกเช้า ควรเพิ่มมาตรการจัดส่งแบบไร้สัมผัส เพื่อสร้างความมั่นใจและปลอดภัยให้กับทั้งลูกค้าและคนจัดส่งเอง โดยมีวิธีการคือให้ลูกค้าชําระเงินด้วยบัตรเครดิตหรือช่องทางการชําระเงินออนไลน์ต่าง ๆ และเชิญลูกค้าหยิบถุงบรรจุอาหาร\nออกจากกระเป๋าจัดส่งเอง โดยเว้นระยะห่างในการยืนรอของผู้ส่งประมาณ1-2เมตร\n3.การขายเฉพาะหน้าร้าน (Take Home only)\nจากมาตรการลดการพบปะกันในสังคม ส่งผลให้ร้านอาหารต้องปรับรูปแบบการบริการใหม่โดยไม่ให้ลูกค้านั่งรับประทานในร้านและให้ลูกค้าซื้อกลับไปรับประทานที่บ้านเท่านั้น แต่ขณะเดียวกันก็อาจจัดให้มีโปรโมชั่นจูงใจมากขึ้น เนื่องจากการซื้อกลับบ้านเป็นการลดค่าใช้จ่ายในการจัดเก็บและให้บริการของร้านอาหารอยู่แล้ว\n4.ปรับพื้นที่ให้เป็นSocial Distancing\nร้านอาหารควรจัดพื้นที่สําหรับการต่อแถวซื้ออาหารที่กลับบ้าน (Take Home only)ให้สอดคล้องกับการทําSocial Distancingหรือการเว้นระยะห่างทางสังคม โดยกําหนดพื้นที่ยืนต่อแถวซึ่งแต่ละตําแหน่งควรมีระยะห่างกันอย่างน้อย1–2เมตร พร้อมทั้งปรับพื้นที่ต่อแถวให้โล่งเพื่อให้อากาศถ่ายเทได้สะดวก\n5.เพิ่มมาตรการทําความสะอาด\nเพื่อให้เกิดความปลอดภัยและมั่นใจทั้งต่อตัวลูกค้าและพนักงานในร้าน ผู้ประกอบการควรเพิ่มมาตรการทําความสะอาดที่เข้มงวดมากขึ้น ด้วยการฉีดพ่นแอลกอฮอล์ ล้างน้ํายาฆ่าเชื้อ แจกหน้ากากอนามัยและถุงมือให้กับพนักงาน รวมถึงการทําความสะอาดภาชนะให้ดีเป็นพิเศษ โดยทางร้านควรประชาสัมพันธ์มาตรการเหล่านี้ผ่านช่องทางต่าง ๆ เพื่อสร้างความมั่นใจให้กับลูกค้าและพนักงานได้ด้วย\n6.จัดทําVoucherพิเศษ สําหรับใช้บริการหลังสิ้นสุดวิกฤต\nหนึ่งไอเดียที่จะช่วยเพิ่มรายได้ให้ร้านอาหารในยามวิกฤต คือการจัดทําบัตรVoucherขายให้แก่ลูกค้าเพื่อให้ลูกค้าสามารถนํากลับมาใช้บริการได้เมื่อสถานการณ์ดีขึ้น โดยจัดเป็นราคาโปรโมชั่นที่ถูกกว่าปกติเพื่อดึงดูดให้ลูกค้าซื้อเก็บไว้ใช้ เพื่อให้ผู้ประกอบการสามารถนํารายได้ในส่วนนี้มาแบ่งเบาภาระค่าใช้จ่ายต่าง ๆ ที่เกิดในปัจจุบัน ทั้งนี้ผู้ประกอบการจําเป็นต้องบริหารจัดการเงินทุนให้ดี เพื่อให้มีทุนสํารองไว้ดําเนินกิจการต่อหลังจากฟื้นจากวิกฤตแล้วด้วย\nอ้างอิง:\nhttps://www.smethailandclub.com/marketing-5583-id.html',
#  'url': 'https://www.thaigov.go.th/news/contents/details/29063'}

# %%
list_text = list(glob.glob(os.path.join("*","*.txt")))+list(glob.glob(os.path.join("*","*","*.txt")))+list(glob.glob(os.path.join("*","*","*","*.txt")))

# %%
list_text=list(set(list_text))

# %%
len(list_text)
# Out:
# 28555

# %%
list_data=[]
for i in tqdm(list_text):
    list_data.append(clean(i))
# Out:
#   0%|          | 0/28555 [00:00<?, ?it/s]

# %%
list_data[-1]
# Out:
# {'title': 'รัฐบาลไทย-ข่าวทำเนียบรัฐบาล- ปลัด พม. เปิดงาน “เปิดพื้นที่สร้างบ้านหลังใหม่ เพื่ออนาคตที่สดใสของลูกหลานชาวชุมชนริมคลอง”',
#  'context': 'วันอาทิตย์ที่ 2 เมษายน 2560\nปลัด พม. เปิดงาน “เปิดพื้นที่สร้างบ้านหลังใหม่ เพื่ออนาคตที่สดใสของลูกหลานชาวชุมชนริมคลอง”\nปลัด พม. เปิดงาน “เปิดพื้นที่สร้างบ้านหลังใหม่ เพื่ออนาคตที่สดใสของลูกหลานชาวชุมชนริมคลอง” พร้อมรื้อย้ายบ้านที่ชุมชนหลังกรมวิทยาศาสตร์ทหารบก ริมคลองลาดพร้าว เพื่อสร้างบ้านใหม่อีก 113 หลัง\nวันนี้ (2 เม.ย. 60) เวลา 15.30 น. นายไมตรี อินทุสุต ปลัดกระทรวงการพัฒนาสังคมและความมั่นคงของมนุษย์ (ปลัด พม.) เป็นประธานในพิธีเปิดงาน “เปิดพื้นที่สร้างบ้านหลังใหม่ เพื่ออนาคตที่สดใสของลูกหลานชาวชุมชนริมคลอง” พร้อมด้วย นายสมชาติ ภาระสุวรรณ รองผู้อํานวยการฯ รักษาการตําแหน่งผู้อํานวยการสถาบันพัฒนาองค์กรชุมชน (องค์การมหาชน) นายสมคิด สมศรี อธิบดีกรมกิจการผู้สูงอายุ พ.อ.พรประสิทธิ์ กล่ําสมบัติ รองเจ้ากรมวิทยาศาสตร์ทหารบก พ.ท.เพื่อชาติ อุไรเลิศ ผู้บังคับกองพันที่ 1 กรมทหารราบที่ 11 รักษาพระองค์ ผู้แทนเขตจตุจักร ชาวชุมชน และเจ้าหน้าที่สถาบันพัฒนาองค์กรชุมชน (องค์การมหาชน) (พอช.)เข้าร่วมงาน จํานวนทั้งสิ้น 200 คน โดยผู้เข้าร่วมงานได้ช่วยกันรื้อย้ายบ้านเฟสแรกจํานวน 14 หลัง ออกจากแนวก่อสร้างเขื่อนระบายน้ํา จากบ้านทั้งหมดในชุมชน จํานวน 113 หลังคาเรือน ณ ชุมชนหลังกรมวิทยาศาสตร์ทหารบก ริมคลองลาดพร้าว เขตจตุจักร กรุงเทพฯ\nนายไมตรี กล่าวว่า สําหรับชุมชนหลังกรมวิทยาศาสตร์ทหารบกมีเนื้อที่ทั้งหมดประมาณ 4 ไร่ 41 ตารางวา ได้รับสัญญาเช่าจากกรมธนารักษ์ตั้งแต่เดือนมีนาคม 2559 ระยะเวลาเช่า 30 ปี ในอัตราตารางวาละ 1.75 บาทต่อเดือน โดยหลังจากรื้อย้ายบ้านเฟสแรกออกจากแนวเขื่อนแล้ว จะเริ่มก่อสร้างบ้านใหม่ทันที และหลังจากนั้นจะทยอยรื้อและสร้างบ้านใหม่ทั้งชุมชนจํานวน 113 หลัง รวม 122 ครัวเรือน ให้แล้วเสร็จภายในสิ้นปี 2560 นี้ ทั้งนี้ ชุมชนหลังกรมวิทยาศาสตร์ฯ ได้รับงบประมาณสนับสนุน จากทางสถาบันพัฒนาองค์กรชุมชน (องค์การมหาชน) (พอช.) รวมทั้งสิ้น 49,592,500 บาท ประกอบด้วย งบช่วยเหลือลดภาระหนี้สิน จํานวน 8,784,000 บาท งบอุดหนุนจากรัฐบาล จํานวน 3,050,000 บาท งบสาธารณูปโภค 6,100,000 บาท และสินเชื่อก่อสร้างบ้านจํานวน 31,658,500 บาท ซึ่งประมาณหลังละ 210,000-360,000 บาท ระยะเวลาผ่อนส่ง 15 ปี อัตราดอกเบี้ยร้อยละ 4 บาทต่อปี\nนายไมตรี กล่าวต่อไปว่า การก่อสร้างชุมชนดังกล่าว มีแบบบ้าน 2 แบบ คือ บ้านแถว 1 ชั้น ขนาด 4X7 เมตร ราคา 210,000 บาท ผ่อนชําระเดือนละ 1,017 บาท และบ้านแถว 2 ชั้น ขนาด 6X7 เมตร ราคา 360,000 บาทผ่อนชําระเดือนละ 2,219 บาท สําหรับการบริหารจัดการนั้น ชาวชุมชนได้เข้าร่วมกับสหกรณ์เคหสถานบ้านมั่นคงคลองลาดพร้าวจตุจักร จํากัด เพื่อบริหารจัดการการก่อสร้างบ้าน และดูแลเรื่องสินเชื่อจาก พอช. โดยมีคณะกรรมการสหกรณ์ฯ จํานวน 15 คน ช่วยกันบริหารงาน รวมทั้งจะช่วยกันพัฒนาชุมชนในด้านต่างๆ เช่น เรื่องสิ่งแวดล้อม ไม่ให้มีการปล่อยน้ําเสียลงคลอง โดยใช้ถังดักไขมันในครัวเรือน และส่งเสริมอาชีพชาวชุมชนให้มีรายได้ ฯลฯ\nนายไมตรี กล่าวต่ออีกว่า สําหรับการจัดงาน “เปิดพื้นที่สร้างบ้านหลังใหม่ เพื่ออนาคตที่สดใสของลูกหลานชาวชุมชนริมคลอง” ที่ชุมชนหลังกรมวิทยาศาสตร์ฯ ในวันนี้ เป็นการรื้อย้ายบ้านจํานวน 14 หลัง ออกจากแนวก่อสร้างเขื่อนระบายน้ํา จากบ้านทั้งหมดในชุมชน จํานวน 113 หลังคาเรือน เพื่อให้กรุงเทพมหานครได้ก่อสร้างเขื่อนระบายน้ําป้องกันน้ําท่วมในเขตกรุงเทพฯ ซึ่งเป็นนโยบายสําคัญของรัฐบาล พลเอกประยุทธ์ จันทร์โอชา นายกรัฐมนตรี ที่ได้ ให้ความสําคัญกับการพัฒนาคลองลาดพร้าวให้เกิดประโยชน์ สามารถป้องกันน้ําท่วมได้ และในอนาคตจะพัฒนาคลองให้กลับมาใสสะอาด เป็นแหล่งท่องเที่ยวทางน้ํา และมีทางขี่จักรยานหรือไบค์เลนเลียบคลอง ในขณะที่ชาวชุมชนจะมีที่อยู่อาศัยใหม่ที่มีความมั่นคง สวยงาม มีสภาพแวดล้อมที่ดีมีบ้านเรือนที่เป็นระเบียบ มีสวนหย่อมเอาไว้นั่งเล่นหรือออกกําลังกาย มีต้นไม้เขียวขจี ร่มรื่น มีที่อยู่อาศัยที่ดีไว้รองรับบุตรหลานในอนาคตต่อไป\nนายไมตรี กล่าวเพิ่มเติมว่า การดําเนินงานของ พอช. ขณะนี้ได้สนับสนุนการพัฒนาที่อยู่อาศัยเสร็จเรียบร้อยแล้ว จํานวนทั้งสิ้น 726 หลังคาเรือน จากเป้าหมายภายในสิ้นปีนี้ จํานวน 33 ชุมชน รวม 3,672 ครัวเรือน และจะก่อสร้างให้แล้วเสร็จตามแผนงานระยะเวลา 3 ปี (พ.ศ.2559-2561) รวมเป้าหมาย 52 ชุมชน จํานวน 7,081 ครัวเรือน ส่วนชุมชนที่กําลังรื้อย้ายและก่อสร้างบ้านอยู่ในขณะนี้ อาทิ เขตห้วยขวาง ชุมชนหลังโรงเรียนสมาคมไทย-ญี่ปุ่น ชุมชนริมคลองลาดพร้าว ประชาอุทิศเขตจตุจักร ชุมชนวังหิน ชุมชนหลังกรมวิทยาศาสตร์ ชุมชนหลัง ว.ค.จันทรเกษม ชุมชนพหลโยธิน 32 เขตบางเขน ชุมชนวัดบางบัว ชุมชนสามัคคีร่วมใจ เขตหลักสี่ ชุมชนบางบัวร่วมใจพัฒนา เขตดอนเมือง ชุมชนร่วมมิตรแรงศรัทธา เขตสายไหม ชุมชนเพิ่ ...
#  'url': 'http://www.thaigov.go.th/news/contents/details/2828'}

# %%
title=[]
context=[]
url=[]
for d in tqdm(list_data):
    title.append(d["title"])
    context.append(d["context"])
    url.append(d["url"])
# Out:
#   0%|          | 0/28555 [00:00<?, ?it/s]

# %%
df = pd.DataFrame.from_dict(
    {
        "title": title,
        "context": context,
        "url": url,
    }
)

# %%
df
# Out:
#                                                    title  \
# 0      รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-“O2O-Village Groce...
# 1      รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-กระทรวงเกษตรและสหก...
# 2      รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-รองนายกรัฐมนตรี อน...
# 3      รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-นายกรัฐมนตรีกล่าวถ...
# 4      รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-รัฐมนตรีเกษตรฯ เผย...
# ...                                                  ...
# 28550  รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-พาณิชย์เผยญี่ปุ่นน...
# 28551  รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-ปิดประชุมผู้นำอาชี...
# 28552  รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-ม.ล.ปนัดดาฯ เสริมส...
# 28553  รัฐบาลไทย-ข่าวทำเนียบรัฐบาล-เปิดตัวหุ่นยนต์บริ...
# 28554  รัฐบาลไทย-ข่าวทำเนียบรัฐบาล- ปลัด พม. เปิดงาน ...
#
#                                                  context  \
# 0      วันอังคารที่ 23 ตุลาคม 2561\n“O2O-Village Groc...
# 1      วันพุธที่ 14 มีนาคม 2561\nกระทรวงเกษตรและสหกรณ...
# 2      วันอังคารที่ 17 มีนาคม 2563\nรองนายกรัฐมนตรี อ...
# 3      วันจันทร์ที่ 29 มกราคม 2561\nนายกรัฐมนตรีกล่าว...
# 4      วันพฤหัสบดีที่ 27 เมษายน 2560\nรัฐมนตรีเกษตรฯ ...
# ...                                                  ...
# 28550  วันจันทร์ที่ 30 ตุลาคม 2560\nพาณิชย์เผยญี่ปุ่น...
# 28551  วันอังคารที่ 6 สิงหาคม 2562\nปิดประชุมผู้นําอา...
# 28552  วันพุธที่ 23 พฤษภาคม 2561\nม.ล.ปนัดดาฯ เสริมสร...
# 28553  วันอังคารที่ 27 ธันวาคม 2559\nเปิดตัวหุ่นยนต์บ...
# 28554  วันอาทิตย์ที่ 2 เมษายน 2560\nปลัด พม. เปิดงาน ...
#
#                                                      url
# 0      https://www.thaigov.go.th/news/contents/detail...
# 1      http://www.thaigov.go.th/news/contents/details...
# 2      https://www.thaigov.go.th/news/contents/detail...
# 3      http://www.thaigov.go.th/news/contents/details...
# 4      http://www.thaigov.go.th/news/contents/details...
# ...                                                  ...
# 28550  http://www.thaigov.go.th/news/contents/details...
# 28551  https://www.thaigov.go.th/news/contents/detail...
# 28552  http://www.thaigov.go.th/news/contents/details...
# 28553  http://www.thaigov.go.th/news/contents/details...
# 28554  http://www.thaigov.go.th/news/contents/details...
#
# [28555 rows x 3 columns]

# %%
from datasets import Dataset

# %%
ds = Dataset.from_pandas(df)

# %%
ds.push_to_hub("pythainlp/thaigov-corpus")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
